# %% [markdown]
# ## 极限学习机--Regression Example
# 训练部分，目的：求出$W_{out}$，随机初始化$W$和$b$
# $$ H = sigmoid(Wx_{train}+b)\\ H^{+}=H\text{的广义逆}$$
# $$ W_{out} = H^{+}{y_{train}} \text{(需要将 y 转成 one-hot)}$$
# 测试部分
# $$ prediciton = sigmoid(Wx_{test}+b)W_{out}$$

# %%
from sklearn import datasets

Boston = datasets.load_boston()
X, y = Boston.data, Boston.target

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=19)

# %% [markdown]
# 需要标准化，不然会产生很大的极端值

# %%
from sklearn.preprocessing import StandardScaler

standard = StandardScaler()
standard.fit(X_train)
X_train_standard = standard.transform(X_train)
X_test_standard = standard.transform(X_test)

# %% [markdown]
# 导入 ELM 框架

# %%
from frames.ELM import ELMRegression

# %%
# hidden_nodes 隐藏层神经元个数
elm = ELMRegression(hidden_nodes=150)

# %%
elm.fit(X_train_standard, y_train)

# %%
elm.score(X_test_standard, y_test)
# Out:
# mse: 36.53784806705649, rmse: 6.044654503530908, mae: 3.9015133681138217, r2: 0.6507986992095312
# (36.53784806705649, 6.044654503530908, 3.9015133681138217, 0.6507986992095312)

# %%
import os

save_path = 'Example_save_resultes/Regression/save_png'
if not os.path.exists(save_path):
    os.makedirs(save_path)
save_file = os.path.join(save_path, 'elm_regression.png')
elm.result_plot(X_test_standard, y_test, save_file, is_show=True)
# Out:
# Save the picture successfully!

# %% [markdown]
# ### 使用网格搜索，调用 GridSearch 里面的 ELMRegressionGridSearch 函数

# %%
from frames.GridSearch import ElmRegressionGridSearch

# hidden_nodes 搜索上限
# gap 间隔多少神经元进行搜索，默认 10
# is_show 是否展示结果图
prediction = ElmRegressionGridSearch(X_train_standard, X_test_standard, y_train, y_test, hidden_nodes=200, gap=5, is_show=True)
# Out:
# the neuron numbers of hidden layer:  5
# mse: 112.73315087131482, rmse: 10.617586866671486, mae: 7.240146834453291, r2: -0.07741875915142571
# ================================
# the neuron numbers of hidden layer:  10
# mse: 74.22703995776796, rmse: 8.615511590019942, mae: 5.798311690620109, r2: 0.29059371916188415
# ================================
# the neuron numbers of hidden layer:  15
# mse: 35.86622192536119, rmse: 5.9888414510121395, mae: 4.050694698641928, r2: 0.6572175972763918
# ================================
# the neuron numbers of hidden layer:  20
# mse: 36.360250653819, rmse: 6.029946156792696, mae: 4.072903193079559, r2: 0.6524960418555932
# ================================
# the neuron numbers of hidden layer:  25
# mse: 35.421519219875414, rmse: 5.951598039171951, mae: 3.754228964936274, r2: 0.6614677316284663
# ================================
# the neuron numbers of hidden layer:  30
# mse: 34.330508240559446, rmse: 5.8592242012539035, mae: 3.8568006462851483, r2: 0.6718947948877644
# ================================
# the neuron numbers of hidden layer:  35
# mse: 41.83244743066207, rmse: 6.467800818722085, mae: 4.039336444668002, r2: 0.6001968963463116
# ================================
# the neuron numbers of hidden layer:  40
# mse: 32.91453207460322, rmse: 5.737118795580515, mae: 3.574623662751468, r2: 0.6854276312532983
# ================================
# the neuron numbers of hidden layer:  45
# mse: 34.80337937886994, rmse: 5.899438903732281, mae: 3.7807426605436647, r2: 0.6673754478178099
# ================================
# the neuron numbers of hidden layer:  50
# mse: 32.69749141442774, rmse: 5.718172034350466, mae: 3.618579584068151, r2: 0.6875019428197213
# ================================
# the neuron numbers of hidden layer:  55
# mse: 29.011546911038558, rmse: 5.386236804211133, mae: 3.422354470633273, r2: 0.722729431117958
# ================================
# the neuron numbers of hidden layer:  60
# mse: 31.0032434983124, rmse: 5.5680556299584865, mae: 3.6068925929571076, r2: 0.7036942915065738
# ================================
# the neuron numbers of hidden layer:  65
# mse: 41.430647971329044, rmse: 6.436664351302547, mae: 3.7255429337665817, r2: 0.604036993705042
# ================================
# the neuron numbers of hidden layer:  70
# mse: 28.38734867728176, rmse: 5.3279779163658105, mae: 3.4082888335921497, r2: 0.7286950488735233
# ================================
# the neuron numbers of hidden layer:  75
# mse: 29.57060500754296, rmse: 5.437886078941243, mae: 3.2197237985743166, r2: 0.7173863738541997
# ================================
# the neuron numbers of hidden layer:  80
# mse: 26.53912604322342, rmse: 5.151613926064668, mae: 3.3650126424519313, r2: 0.7463589722326407
# ================================
# the neuron numbers of hidden layer:  85
# mse: 27.94242105424731, rmse: 5.286059123226613, mae: 3.4174262653694076, r2: 0.7329473328185466
# ================================
# the neuron numbers of hidden layer:  90
# mse: 35.69989918138439, rmse: 5.97493926173182, mae: 3.6909361466983843, r2: 0.6588071851043654
# ================================
# the neuron numbers of hidden layer:  95
# mse: 29.64394487165999, rmse: 5.444625319676276, mae: 3.260145635092751, r2: 0.7166854465335085
# ================================
# the neuron numbers of hidden layer:  100
# mse: 24.045492260268258, rmse: 4.903620321789632, mae: 3.403274764483377, r2: 0.7701912504528822
# ================================
# the neuron numbers of hidden layer:  105
# mse: 28.9347564178065, rmse: 5.379103681637536, mae: 3.2595237758848223, r2: 0.7234633369592587
# ================================
# the neuron numbers of hidden layer:  110
# mse: 21.341593303457188, rmse: 4.619696234976623, mae: 2.8623462645205473, r2: 0.7960330852317546
# ================================
# the neuron numbers of hidden layer:  115
# mse: 22.41136590789672, rmse: 4.73406441737929, mae: 3.135690038226126, r2: 0.7858090024030477
# ================================
# the neuron numbers of hidden layer:  120
# mse: 27.080152690455005, rmse: 5.203859403409647, mae: 3.1272245464026165, r2: 0.7411882460139306
# ================================
# the neuron numbers of hidden layer:  125
# mse: 24.48291137782721, rmse: 4.9480209556778565, mae: 3.1302927944492933, r2: 0.7660107271620229
# ================================
# the neuron numbers of hidden layer:  130
# mse: 20.18659300877772, rmse: 4.492949255085986, mae: 2.957302539326933, r2: 0.8070717102918631
# ================================
# the neuron numbers of hidden layer:  135
# mse: 23.983215618266158, rmse: 4.897266137169407, mae: 3.0518536634622913, r2: 0.7707864438084429
# ================================
# the neuron numbers of hidden layer:  140
# mse: 21.45189787914015, rmse: 4.63161935818782, mae: 3.154507737675407, r2: 0.794978876969655
# ================================
# the neuron numbers of hidden layer:  145
# mse: 25.834617935945953, rmse: 5.082776597091983, mae: 3.0578402606829322, r2: 0.7530921314221809
# ================================
# the neuron numbers of hidden layer:  150
# mse: 39.71013622061821, rmse: 6.301597910103294, mae: 3.741400270478224, r2: 0.6204803523908321
# ================================
# the neuron numbers of hidden layer:  155
# mse: 23.9231502776555, rmse: 4.891129754735147, mae: 3.049344776035794, r2: 0.7713605032066638
# ================================
# the neuron numbers of hidden layer:  160
# mse: 38.163670044143714, rmse: 6.177675132616129, mae: 3.99232334627745, r2: 0.6352603142392219
# ================================
# the neuron numbers of hidden layer:  165
# mse: 23.910796428512594, rmse: 4.889866708665236, mae: 3.0453861428182147, r2: 0.7714785720152744
# ================================
# the neuron numbers of hidden layer:  170
# mse: 43.109818325136956, rmse: 6.565806753563263, mae: 3.809695850699821, r2: 0.5879887450308898
# ================================
# the neuron numbers of hidden layer:  175
# mse: 30.794588123415295, rmse: 5.5492871725488575, mae: 3.522053097318383, r2: 0.705688462816205
# ================================
# the neuron numbers of hidden layer:  180
# mse: 30.494863545477024, rmse: 5.522215456270882, mae: 3.278879185832085, r2: 0.7085530051478397
# ================================
# the neuron numbers of hidden layer:  185
# mse: 22.814017811262776, rmse: 4.776402182737837, mae: 3.197497334505897, r2: 0.7819607580246942
# ================================
# the neuron numbers of hidden layer:  190
# mse: 42.16926674770234, rmse: 6.493786780277155, mae: 3.8229235660051013, r2: 0.5969778303677691
# ================================
# the neuron numbers of hidden layer:  195
# mse: 38.740888451294836, rmse: 6.2242178987640555, mae: 3.887185411524636, r2: 0.6297436943702179
# ================================
# ============ The end!!! ==============
# the neuron numbers of hidden layer:  130
# mse: 20.18659300877772, rmse: 4.492949255085986, mae: 2.957302539326933, r2: 0.8070717102918631

# %% [markdown]
# 找到最好的 hidden number 是 130

# %%
elm2 = ELMRegression(hidden_nodes=130)
elm2.fit(X_train_standard, y_train)

# %%
save_path = 'Example_save_resultes/Regression/save_png'
if not os.path.exists(save_path):
    os.makedirs(save_path)
save_file = os.path.join(save_path, 'elm_regression2.png')
elm.result_plot(X_test_standard, y_test, save_file, is_show=True)
# Out:
# Save the picture successfully!

# %% [markdown]
# ### 保存值

# %%
result_path = './Example_save_resultes/Regression/'
if not os.path.exists(result_path):
    os.makedirs(result_path)
results_file = os.path.join(result_path, 'ElmRegression.csv')
elm.save_result(is_standard=True, Dimensionality_reduction_method='None', save_path=results_file)
# Out:
# Save results success!
